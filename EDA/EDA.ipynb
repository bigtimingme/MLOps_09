# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import missingno as msno

# %%
path = 'C:\\Users\\User\Desktop\\Proyecto_MLOps_SoyHenry\\files\\total_df.csv'
path_2 = 'C:\\Users\\User\Desktop\\Proyecto_MLOps_SoyHenry\\files\\ratings_by_quantity.csv'

# %%
df = pd.read_csv(path)
ratings_by_quantity = pd.read_csv(path_2)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.drop('id',axis=1,inplace=True)

# %%
msno.bar(df)
plt.show()

# %%
plt.figure(figsize= (25,12))
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# Columnas con problemas de valores faltantes: director, cast,country,date_added,duration_int y duration_type.

# %%
msno.bar(ratings)
plt.show()

# %%
plt.figure(figsize= (25,12))
sns.heatmap(ratings.isnull(), cbar=False)
plt.show()

# %% [markdown]
# No hay valores faltantes en el dataframe de ratings

# %%
ratings_by_quantity.set_index('key_0')
# Out:
#         Unnamed: 0  mean_rating  user_rating
# key_0
# as1              0     3.467131          502
# as10             1     3.439571          513
# as100            2     3.609302          430
# as1000           3     3.556701          485
# as1001           4     3.585288          469
# ...            ...          ...          ...
# ns995        22993     3.515625          448
# ns996        22994     3.626518          494
# ns997        22995     3.530526          475
# ns998        22996     3.582645          484
# ns999        22997     3.494781          479
#
# [22998 rows x 3 columns]

# %%
ratings_by_quantity.drop('Unnamed: 0',axis=1,inplace=True)

# %%
visualizacion = sns.relplot(data=ratings_by_quantity, x="user_rating", y="mean_rating")
visualizacion.set_xlabels('Cantidad de reseñas por pelicula')
visualizacion.set_ylabels('Rating promedio de la pelicula')

# %% [markdown]
# Como vemos, no hay correlación entre la cantidad de reseñas de una película y el puntaje promedio dado a esa misma.

# %%
sns.histplot(ratings_by_quantity['mean_rating'])
# Out:
# <AxesSubplot: xlabel='mean_rating', ylabel='Count'>

# %% [markdown]
# Valor promedio de las críticas: entre 3,3 y 3,8.

# %%
sns.histplot(ratings_by_quantity['user_rating'])
# Out:
# <AxesSubplot: xlabel='user_rating', ylabel='Count'>

# %% [markdown]
# Cantidad de reseñas de una misma película: entre 400 críticas y 560
